# %%
# !pip install easyocr
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      -------------------------- ------------- 41.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# ...
#   Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# ...
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.9 MB 2.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.3/2.9 MB 3.6 MB/s eta 0:00:01
#    -------- ------------------------------- 0.6/2.9 MB 4.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/2.9 MB 5.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.2/2.9 MB 5.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.4/2.9 MB 5.2 MB/s eta 0:00:01
#    -------------------- ------------------- 1.5/2.9 MB 4.6 MB/s eta 0:00:01
# ...

# %%
import easyocr
import cv2

# %%
ocr = easyocr.Reader(['en'], gpu=True)

def perform_ocr_on_image(img, coordinates):
    x, y, w, h = map(int, coordinates)
    cropped_img = img[y:h, x:w]

    gray_img = cv2.cvtColor(cropped_img, cv2.COLOR_RGB2GRAY)
    results = ocr.readtext(gray_img)

    text = ""
    for res in results:
        if len(results) == 1 or (len(res[1]) > 6 and res[2] > 0.2):
            text = res[1]

    return str(text)
